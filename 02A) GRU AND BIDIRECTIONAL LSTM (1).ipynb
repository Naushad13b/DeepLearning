# %%
#https://towardsdatascience.com/predictive-analytics-time-series-forecasting-with-gru-and-bilstm-in-tensorflow-87588c852915
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import warnings
#warnings.filterwarnings('ignore')
from scipy import stats
# %matplotlib inline
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential, layers, callbacks
from tensorflow.keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional

# %%
tf.random.set_seed(1234)

# %%
# Import data using datetime and set index to datetime
df = pd.read_csv(r'C:\Users\91783\Desktop\DataSet\1_Bhiwadi\Book_1_PM.csv',
                                parse_dates=['Date'],
                                index_col=['Date'])

df.head()
# Out:
#              PM2.5
# Date
# 2021-01-01  228.53
# 2021-02-01  222.37
# 2021-03-01  128.14
# 2021-04-01   68.44
# 2021-05-01   62.51

# %%
df
# Out:
#              PM2.5
# Date
# 2021-01-01  228.53
# 2021-02-01  222.37
# 2021-03-01  128.14
# 2021-04-01   68.44
# 2021-05-01   62.51
# ...            ...
# 2021-12-27   92.11
# 2021-12-28  124.25
# 2021-12-29  105.15
# 2021-12-30  161.22
# 2021-12-31  156.41
#
# [365 rows x 1 columns]

# %%
# Split train data and test data
#train_size = int(len(df)*0.8)
train_size = 300
train_data = df.iloc[:train_size]
test_data = df.iloc[train_size:]

# %%
scaler = MinMaxScaler().fit(train_data)
train_scaled = scaler.transform(train_data)
test_scaled = scaler.transform(test_data)

# %%
# Create input dataset
def create_dataset (X, look_back = 1):
    Xs, ys = [], []
 
    for i in range(len(X)-look_back):
        v = X[i:i+look_back]
        Xs.append(v)
        ys.append(X[i+look_back])
 
    return np.array(Xs), np.array(ys)
LOOK_BACK = 30
X_train, y_train = create_dataset(train_scaled,LOOK_BACK)
X_test, y_test = create_dataset(test_scaled,LOOK_BACK)
# Print data shape
print('X_train.shape: ', X_train.shape)
print('y_train.shape: ', y_train.shape)
print('X_test.shape: ', X_test.shape) 
print('y_test.shape: ', y_test.shape)
# Out:
# X_train.shape:  (270, 30, 1)
# y_train.shape:  (270, 1)
# X_test.shape:  (35, 30, 1)
# y_test.shape:  (35, 1)

# %%
# Create BiLSTM model
def create_bilstm(units):
    model = Sequential()
    # Input layer
    model.add(Bidirectional(
              LSTM(units = units, return_sequences=True), 
              input_shape=(X_train.shape[1], X_train.shape[2])))
    # Hidden layer
    model.add(Bidirectional(LSTM(units = units)))
    model.add(Dense(1))
    #Compile model
    model.compile(optimizer='adam',loss='mse')
    return model
model_bilstm = create_bilstm(64)
# Create GRU model
def create_gru(units):
    model = Sequential()
    # Input layer
    model.add(GRU (units = units, return_sequences = True, 
    input_shape = [X_train.shape[1], X_train.shape[2]]))
    model.add(Dropout(0.2)) 
    # Hidden layer
    model.add(GRU(units = units)) 
    model.add(Dropout(0.2))
    model.add(Dense(units = 1)) 
    #Compile model
    model.compile(optimizer='adam',loss='mse')
    return model
model_gru = create_gru(64)

# %%
def fit_model(model):
    early_stop = keras.callbacks.EarlyStopping(monitor = 'val_loss',
                                               patience = 10)
    history = model.fit(X_train, y_train, epochs = 100,  
                        validation_split = 0.2,
                        batch_size = 16, shuffle = False, 
                        callbacks = [early_stop])
    return history
history_gru = fit_model(model_gru)
history_bilstm = fit_model(model_bilstm)
# Out:
# Epoch 1/100
# 14/14 [==============================] - 4s 55ms/step - loss: 0.0706 - val_loss: 0.0213
# Epoch 2/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0207 - val_loss: 0.0170
# Epoch 3/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0253 - val_loss: 0.0165
# Epoch 4/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0199 - val_loss: 0.0162
# Epoch 5/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0216 - val_loss: 0.0151
# Epoch 6/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0214 - val_loss: 0.0155
# Epoch 7/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0207 - val_loss: 0.0152
# Epoch 8/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0205 - val_loss: 0.0150
# Epoch 9/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0211 - val_loss: 0.0150
# Epoch 10/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0209 - val_loss: 0.0148
# Epoch 11/100
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0214 - val_loss: 0.0150
# Epoch 12/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0206 - val_loss: 0.0146
# Epoch 13/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0214 - val_loss: 0.0147
# Epoch 14/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0209 - val_loss: 0.0148
# Epoch 15/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0202 - val_loss: 0.0143
# Epoch 16/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0201 - val_loss: 0.0142
# Epoch 17/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0189 - val_loss: 0.0141
# Epoch 18/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0201 - val_loss: 0.0146
# Epoch 19/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0209 - val_loss: 0.0140
# Epoch 20/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0198 - val_loss: 0.0142
# Epoch 21/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0208 - val_loss: 0.0147
# Epoch 22/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0212 - val_loss: 0.0139
# Epoch 23/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0204 - val_loss: 0.0140
# Epoch 24/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0187 - val_loss: 0.0137
# Epoch 25/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0187 - val_loss: 0.0139
# Epoch 26/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0192 - val_loss: 0.0136
# Epoch 27/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0197 - val_loss: 0.0137
# Epoch 28/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0196 - val_loss: 0.0136
# Epoch 29/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0203 - val_loss: 0.0138
# Epoch 30/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0197 - val_loss: 0.0136
# Epoch 31/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0191 - val_loss: 0.0136
# Epoch 32/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0196 - val_loss: 0.0139
# Epoch 33/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0208 - val_loss: 0.0135
# Epoch 34/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0202 - val_loss: 0.0135
# Epoch 35/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0203 - val_loss: 0.0137
# Epoch 36/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0197 - val_loss: 0.0132
# Epoch 37/100
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0189 - val_loss: 0.0137
# Epoch 38/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0204 - val_loss: 0.0137
# Epoch 39/100
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0200 - val_loss: 0.0131
# Epoch 40/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0180 - val_loss: 0.0131
# Epoch 41/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0185 - val_loss: 0.0138
# Epoch 42/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0209 - val_loss: 0.0133
# Epoch 43/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0203 - val_loss: 0.0130
# Epoch 44/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0191 - val_loss: 0.0132
# Epoch 45/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0185 - val_loss: 0.0135
# Epoch 46/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0187 - val_loss: 0.0132
# Epoch 47/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0197 - val_loss: 0.0131
# Epoch 48/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0190 - val_loss: 0.0131
# Epoch 49/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0190 - val_loss: 0.0132
# Epoch 50/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0188 - val_loss: 0.0136
# Epoch 51/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0195 - val_loss: 0.0131
# Epoch 52/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0192 - val_loss: 0.0134
# Epoch 53/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0187 - val_loss: 0.0132
# Epoch 1/100
# 14/14 [==============================] - 6s 110ms/step - loss: 0.0602 - val_loss: 0.0306
# Epoch 2/100
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0352 - val_loss: 0.0201
# Epoch 3/100
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0225 - val_loss: 0.0216
# Epoch 4/100
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0225 - val_loss: 0.0207
# Epoch 5/100
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0213 - val_loss: 0.0213
# Epoch 6/100
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0211 - val_loss: 0.0212
# Epoch 7/100
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0206 - val_loss: 0.0217
# Epoch 8/100
# 14/14 [==============================] - 0s 36ms/step - loss: 0.0205 - val_loss: 0.0212
# Epoch 9/100
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0203 - val_loss: 0.0211
# Epoch 10/100
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0202 - val_loss: 0.0205
# Epoch 11/100
# 14/14 [==============================] - 1s 35ms/step - loss: 0.0200 - val_loss: 0.0202
# Epoch 12/100
# 14/14 [==============================] - 0s 36ms/step - loss: 0.0199 - val_loss: 0.0198
# Epoch 13/100
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0198 - val_loss: 0.0194
# Epoch 14/100
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0197 - val_loss: 0.0191
# Epoch 15/100
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0196 - val_loss: 0.0188
# Epoch 16/100
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0195 - val_loss: 0.0186
# Epoch 17/100
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0194 - val_loss: 0.0184
# Epoch 18/100
# 14/14 [==============================] - 0s 36ms/step - loss: 0.0193 - val_loss: 0.0182
# Epoch 19/100
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0192 - val_loss: 0.0180
# Epoch 20/100
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0192 - val_loss: 0.0179
# Epoch 21/100
# 14/14 [==============================] - 1s 35ms/step - loss: 0.0191 - val_loss: 0.0177
# Epoch 22/100
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0190 - val_loss: 0.0176
# Epoch 23/100
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0189 - val_loss: 0.0175
# Epoch 24/100
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0189 - val_loss: 0.0174
# Epoch 25/100
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0188 - val_loss: 0.0173
# Epoch 26/100
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0187 - val_loss: 0.0171
# Epoch 27/100
# 14/14 [==============================] - 1s 35ms/step - loss: 0.0187 - val_loss: 0.0170
# Epoch 28/100
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0186 - val_loss: 0.0169
# Epoch 29/100
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0186 - val_loss: 0.0168
# Epoch 30/100
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0185 - val_loss: 0.0167
# Epoch 31/100
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0185 - val_loss: 0.0166
# Epoch 32/100
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0184 - val_loss: 0.0164
# Epoch 33/100
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0184 - val_loss: 0.0163
# Epoch 34/100
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0183 - val_loss: 0.0162
# Epoch 35/100
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0183 - val_loss: 0.0161
# Epoch 36/100
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0183 - val_loss: 0.0161
# Epoch 37/100
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0182 - val_loss: 0.0160
# Epoch 38/100
# 14/14 [==============================] - 0s 36ms/step - loss: 0.0182 - val_loss: 0.0159
# Epoch 39/100
# 14/14 [==============================] - 1s 35ms/step - loss: 0.0182 - val_loss: 0.0158
# Epoch 40/100
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0181 - val_loss: 0.0158
# Epoch 41/100
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0181 - val_loss: 0.0157
# Epoch 42/100
# 14/14 [==============================] - 0s 36ms/step - loss: 0.0181 - val_loss: 0.0156
# Epoch 43/100
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0181 - val_loss: 0.0156
# Epoch 44/100
# 14/14 [==============================] - 1s 35ms/step - loss: 0.0181 - val_loss: 0.0155
# Epoch 45/100
# 14/14 [==============================] - 1s 35ms/step - loss: 0.0180 - val_loss: 0.0154
# Epoch 46/100
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0180 - val_loss: 0.0153
# Epoch 47/100
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0180 - val_loss: 0.0152
# Epoch 48/100
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0180 - val_loss: 0.0151
# Epoch 49/100
# 14/14 [==============================] - 1s 35ms/step - loss: 0.0179 - val_loss: 0.0149
# Epoch 50/100
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0179 - val_loss: 0.0148
# Epoch 51/100
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0179 - val_loss: 0.0146
# Epoch 52/100
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0179 - val_loss: 0.0144
# Epoch 53/100
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0178 - val_loss: 0.0143
# Epoch 54/100
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0178 - val_loss: 0.0142
# Epoch 55/100
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0178 - val_loss: 0.0142
# Epoch 56/100
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0177 - val_loss: 0.0143
# Epoch 57/100
# 14/14 [==============================] - 0s 36ms/step - loss: 0.0177 - val_loss: 0.0143
# Epoch 58/100
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0176 - val_loss: 0.0150
# Epoch 59/100
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0177 - val_loss: 0.0148
# Epoch 60/100
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0182 - val_loss: 0.0196
# Epoch 61/100
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0184 - val_loss: 0.0193
# Epoch 62/100
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0183 - val_loss: 0.0181
# Epoch 63/100
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0188 - val_loss: 0.0170
# Epoch 64/100
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0181 - val_loss: 0.0165

# %%
y_test = scaler.inverse_transform(y_test)
y_train = scaler.inverse_transform(y_train)

# %%
def plot_loss (history, model_name):
    plt.figure(figsize = (10, 6))
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Train vs Validation Loss for ' + model_name)
    plt.ylabel('Loss')
    plt.xlabel('epoch')
    plt.legend(['Train loss', 'Validation loss'], loc='upper right')
plot_loss(history_gru, 'GRU')
plot_loss(history_bilstm, 'Bidirectional LSTM')

# %%
# Make prediction
def prediction(model):
    prediction = model.predict(X_test)
    prediction = scaler.inverse_transform(prediction)
    return prediction
prediction_gru = prediction(model_gru)
prediction_bilstm = prediction(model_bilstm)
# Plot test data vs prediction
def plot_future(prediction, model_name, y_test):
    plt.figure(figsize=(10, 6))
    range_future = len(prediction)
    plt.plot(np.arange(range_future), np.array(y_test), 
             label='Test   data')
    plt.plot(np.arange(range_future), 
             np.array(prediction),label='Prediction')
    plt.title('Test data vs prediction for ' + model_name)
    plt.legend(loc='upper left')
    plt.xlabel('Time (day)')
    plt.ylabel('Daily pm2.5 pollution (µg/$m³$)')
plot_future(prediction_gru, 'GRU', y_test)
plot_future(prediction_bilstm, 'Bidirectional LSTM', y_test)
# Out:
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 0s/step

# %%
def evaluate_prediction(predictions, actual, model_name):
    errors = predictions - actual
    mse = np.square(errors).mean()
    rmse = np.sqrt(mse)
    mae = np.abs(errors).mean()
    print(model_name + ':')
    print('Mean Absolute Error: {:.4f}'.format(mae))
    print('Root Mean Square Error: {:.4f}'.format(rmse))
    print("")
evaluate_prediction(prediction_gru, y_test, 'GRU')
evaluate_prediction(prediction_bilstm, y_test, 'Bidirectiona LSTM')
# Out:
# GRU:
# Mean Absolute Error: 31.7480
# Root Mean Square Error: 42.4195
#
# Bidirectiona LSTM:
# Mean Absolute Error: 36.0406
# Root Mean Square Error: 45.1987

# %%
prediction_gru
# Out:
# array([[179.28528 ],
#        [174.09163 ],
#        [168.25368 ],
#        [165.85406 ],
#        [142.60164 ],
#        [150.13663 ],
#        [158.71786 ],
#        [136.06575 ],
#        [136.9948  ],
#        [129.5341  ],
#        [124.60826 ],
#        [105.041534],
#        [ 94.34961 ],
#        [ 95.82907 ],
#        [101.26499 ],
#        [ 98.01717 ],
#        [ 96.565834],
#        [121.30639 ],
#        [123.65956 ],
#        [139.16727 ],
#        [162.10408 ],
#        [154.02286 ],
#        [113.44039 ],
#        [ 98.296074],
#        [128.85072 ],
#        [175.38548 ],
#        [164.91672 ],
#        [154.52069 ],
#        [138.86581 ],
#        [159.69266 ],
#        [168.67406 ],
#        [125.938835],
#        [128.23506 ],
#        [121.11085 ],
#        [139.87741 ]], dtype=float32)

# %%
#for GRU
import matplotlib.pyplot as plt
plt.figure(figsize=(4,4),dpi=80)
plt.scatter(y_test,prediction_gru)
plt.show()

# %%
import seaborn as sb
plt.figure(figsize=(4,4),dpi=80)
sb.regplot(y_test,prediction_gru,ci=None)
# Out:
# <AxesSubplot:>

# %%
#for BIDIRECTIONAL LSTM
import matplotlib.pyplot as plt
plt.figure(figsize=(4,4),dpi=80)
plt.scatter(y_test,prediction_bilstm)
plt.show()

# %%
import seaborn as sb
plt.figure(figsize=(4,4),dpi=80)
sb.regplot(y_test,prediction_bilstm,ci=None)
# Out:
# <AxesSubplot:>
